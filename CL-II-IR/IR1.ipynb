# %%
import nltk
import re

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# Download required resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

# ---------------------------------------
# Input Text
# ---------------------------------------
text = "Natural Language Processing is an important part of Artificial Intelligence. " \
       "It helps computers understand and process human languages!"

print("Original Text:")
print(text)

# ---------------------------------------
# 1. Convert to lowercase
# ---------------------------------------
text = text.lower()

# ---------------------------------------
# 2. Remove punctuation and special characters
# ---------------------------------------
text = re.sub(r'[^a-zA-Z\s]', '', text)

# ---------------------------------------
# 3. Tokenization
# ---------------------------------------
words = word_tokenize(text)

print("\nAfter Tokenization:")
print(words)

# ---------------------------------------
# 4. Stop Word Removal
# ---------------------------------------
stop_words = set(stopwords.words('english'))

filtered_words = []

for word in words:
    if word not in stop_words:
        filtered_words.append(word)

print("\nAfter Stop Word Removal:")
print(filtered_words)

# ---------------------------------------
# 5. Stemming
# ---------------------------------------
stemmer = PorterStemmer()

stemmed_words = []

for word in filtered_words:
    stemmed_words.append(stemmer.stem(word))

print("\nAfter Stemming:")
print(stemmed_words)

# ---------------------------------------
# Final Preprocessed Text
# ---------------------------------------
processed_text = " ".join(stemmed_words)

print("\nFinal Preprocessed Text:")
print(processed_text)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Nistha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Nistha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Nistha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Original Text:
# Natural Language Processing is an important part of Artificial Intelligence. It helps computers understand and process human languages!
#
# After Tokenization:
# ['natural', 'language', 'processing', 'is', 'an', 'important', 'part', 'of', 'artificial', 'intelligence', 'it', 'helps', 'computers', 'understand', 'and', 'process', 'human', 'languages']
#
# After Stop Word Removal:
# ['natural', 'language', 'processing', 'important', 'part', 'artificial', 'intelligence', 'helps', 'computers', 'understand', 'process', 'human', 'languages']
#
# After Stemming:
# ['natur', 'languag', 'process', 'import', 'part', 'artifici', 'intellig', 'help', 'comput', 'understand', 'process', 'human', 'languag']
#
# Final Preprocessed Text:
# natur languag process import part artifici intellig help comput understand process human languag
